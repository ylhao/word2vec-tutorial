# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
NORMAL_EXE_PATH = 'D:/malware_detection_dataset/normal'
MALWARE_EXE_PATH = 'D:/malware_detection_dataset/malware'
MAX_PROCESS_NUM = 2  # 最大进程数

# %%
def analyse_normal():
    
    files = os.listdir(NORMAL_EXE_PATH)
    file_size_list = []
    count = 0
    
    for file in files:
        exe_file = os.path.join(NORMAL_EXE_PATH, file)
        file_size = os.path.getsize(exe_file)
        file_size = file_size / 1024 / 1024  # 转为 MB
        file_size_list.append(file_size)
        if file_size > 10:
            count += 1
    print('软件总数：', len(file_size_list))
    print('>10MB 的软件数量：', count)
    plt.title('良性软件大小统计')
    plt.xlabel('Size(MB)')
    plt.ylabel('百分比')
    plt.hist(file_size_list, bins=50, range=(0, 10), color='steelblue', normed=True )
    plt.show()

# %%
def analyse_malware():
    
    files = os.listdir(MALWARE_EXE_PATH)
    file_size_list = []
    count = 0
    
    for file in files:
        exe_file = os.path.join(MALWARE_EXE_PATH, file)
        file_size = os.path.getsize(exe_file)
        file_size = file_size / 1024 / 1024  # 转为 MB
        file_size_list.append(file_size)
        if file_size > 10:
            print(file)
            count += 1
    print('软件总数：', len(file_size_list))
    print('>10MB 的软件数量：', count)
    plt.title('恶意软件大小统计')
    plt.xlabel('Size(MB)')
    plt.ylabel('百分比')
    plt.hist(file_size_list, bins=50, range=(0, 10), color='steelblue', normed=True )
    plt.show()

# %%
analyse_normal()
# Out:
# 软件总数： 9355
# >10MB 的软件数量： 591
# c:\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
analyse_malware()
# Out:
# Backdoor.Win32.VB.adl
# Backdoor.Win32.VB.aor
# Backdoor.Win32.VB.apa
# Trojan-Banker.Win32.Banbra.aic
# Trojan-Banker.Win32.Banbra.aim
# Trojan-Banker.Win32.Banbra.bnk
# Trojan-Banker.Win32.Banbra.bws
# Trojan-Banker.Win32.Banbra.cez
# Trojan-Banker.Win32.Banbra.czu
# Trojan-Banker.Win32.Banbra.fvy
# Trojan-Banker.Win32.Banbra.ld
# Trojan-Banker.Win32.Banbra.pe
# Trojan-Banker.Win32.Banbra.qu
# Trojan-Banker.Win32.Banbra.vt
# Trojan-Banker.Win32.Bancos.afn
# Trojan-Banker.Win32.Bancos.ajj
# Trojan-Banker.Win32.Bancos.aln
# Trojan-Banker.Win32.Bancos.bai
# Trojan-Banker.Win32.Bancos.kg
# Trojan-Banker.Win32.Bancos.mk
# Trojan-Banker.Win32.Banker.abhl
# Trojan-Banker.Win32.Banker.cyp
# Trojan-Banker.Win32.Banker.ddz
# Trojan-Banker.Win32.Banker.dhx
# Trojan-Banker.Win32.Banker.dlm
# Trojan-Banker.Win32.Banker.dmi
# Trojan-Banker.Win32.Banker.dwe
# Trojan-Banker.Win32.Banker.evh
# Trojan-Banker.Win32.Banker.fhb
# Trojan-Banker.Win32.Banker.fhc
# Trojan-Banker.Win32.Banker.fja
# ...
